# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.path as mplPath
from matplotlib import cm
import seaborn as sns
import pickle
from tqdm import tqdm
from roifile import ImagejRoi
from scipy.stats import spearmanr
from sklearn.linear_model import LinearRegression

import flexiznam as flz
from cottage_analysis.analysis import common_utils, roi_location
from cottage_analysis.analysis.common_utils import ztest_2d
from cottage_analysis.plotting import style
from cottage_analysis.plotting.style import CM, FONTSIZE_DICT, rect_cm, panel_letter
from cottage_analysis.summary_analysis import get_session_list

from v1_depth_map.paths import get_figures_roots
from v1_depth_map.figure_utils import v1_map

# %%
# Register manuscript font faces (Arial regular, bold, italic, Narrow) and publication rcParams
style.setup_figure_fonts()

# %%
project = "hey2_3d-vision_foodres_20220101"
flexilims_session = flz.get_flexilims_session(project)
READ_ROOT, SAVE_ROOT = get_figures_roots(flexilims_session)
SAVE_ROOT.mkdir(parents=True, exist_ok=True)
recompute_summary = False  # True: rebuild the per-session summary/bootstrap results and re-cache; False: load the cached results

# %% [markdown]
# ## 1. Load Data & Compute Cortical Alignments

# %%
# Load data for calculating proportion of significant RF and cortical alignment
#
# The full cache (rf_neurons_df_all.pkl) is ~14 GB because it carries a per-neuron RF
# map in rf_coef_closedloop / rf_coef_ipsi_closedloop. No panel of this figure reads
# them, so we keep a slim copy without those two columns (~28 MB) and load that.
HEAVY_COLS = ["rf_coef_closedloop", "rf_coef_ipsi_closedloop"]

if recompute_summary:
    project = "hey2_3d-vision_foodres_20220101"
    flexilims_session = flz.get_flexilims_session(project)
    all_sig, all_sig_ipsi, neurons_df_all = rf_plots.load_sig_rf(
        flexilims_session=flexilims_session,
        session_list=get_session_list.get_sessions(
            flexilims_session=flexilims_session,
            exclude_openloop=False,
            exclude_pure_closedloop=False,
            v1_only=True,
        ),
        n_std=6,
    )

    neurons_df_all = roi_location.align_across_mice(neurons_df_all)  # align neuron coordinates across mice
    neurons_df_all.to_pickle(SAVE_ROOT / "rf_neurons_df_all.pkl")
    neurons_df_all.drop(columns=HEAVY_COLS).to_pickle(
        SAVE_ROOT / "rf_neurons_df_slim.pkl", protocol=5
    )

    with open(SAVE_ROOT / "rf_all_sig.pkl", "wb") as f:
        pickle.dump(all_sig, f, protocol=pickle.HIGHEST_PROTOCOL)
    with open(SAVE_ROOT / "rf_all_sig_ipsi.pkl", "wb") as f:
        pickle.dump(all_sig_ipsi, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    slim_path = READ_ROOT / "rf_neurons_df_slim.pkl"
    if not slim_path.exists():
        # One-off migration: build the slim cache from the full one. Needs ~15 GB
        # of RAM for this single cell; afterwards the notebook never touches the
        # full pickle again.
        print("Slim cache missing, building it from rf_neurons_df_all.pkl (slow, ~15 GB RAM)...")
        _df = pd.read_pickle(READ_ROOT / "rf_neurons_df_all.pkl")
        for _c in HEAVY_COLS:
            del _df[_c]
        _df.to_pickle(slim_path, protocol=5)
        del _df
    neurons_df_all = pd.read_pickle(slim_path)
    # rf_all_sig.pkl / rf_all_sig_ipsi.pkl are written by the recompute branch above
    # but no panel of this figure uses them, so they are not loaded here.

# Widefield overview image and hand-drawn V1 outline, both in overview-pixel coordinates
v1_mask_fname = flz.get_data_root("processed", flexilims_session=flexilims_session) / project / "PZAH10.2d/FOVs/V1_mask_2.roi"
overview_fname = flz.get_data_root("processed", flexilims_session=flexilims_session) / project / "PZAH10.2d/FOVs/PZAH10.2d_overview.tif"
overview_img = plt.imread(overview_fname)

# Per-neuron V1 membership: does the neuron's aligned position fall inside the V1
# polygon? This is finer than the `v1` column, which is a per-session flexilims flag
# ("was this session targeted at V1") and is therefore constant within a session.
_x = neurons_df_all["overview_x_aligned"].to_numpy(float)
_y = neurons_df_all["overview_y_aligned"].to_numpy(float)
_h, _w = overview_img.shape[:2]
_inside_img = (
    np.isfinite(_x) & np.isfinite(_y) & (_x >= 0) & (_x < _w) & (_y >= 0) & (_y < _h)
)
neurons_df_all["v1_mask"] = False
neurons_df_all.loc[_inside_img, "v1_mask"] = mplPath.Path(
    ImagejRoi.fromfile(v1_mask_fname).coordinates()
).contains_points(np.column_stack([_x[_inside_img], _y[_inside_img]]))

# Correct preferred depth for viewing angle / eccentricity
neurons_df_all["preferred_depth_corrected"] = neurons_df_all[
    "preferred_depth_closedloop"
] / np.sqrt(
    (np.sin(np.deg2rad(neurons_df_all["rf_azi"])) ** 2)
    * (np.cos(np.deg2rad(neurons_df_all["rf_ele"])) ** 2)
    + (np.sin(np.deg2rad(neurons_df_all["rf_ele"])) ** 2)
)

common_utils.add_one_sided_spearman_significance(
    neurons_df_all,
    rval_col="depth_tuning_test_spearmanr_rval_closedloop",
    pval_col="depth_tuning_test_spearmanr_pval_closedloop",
    out_col="is_depth_neuron",
)

use_v1_mask = False  # True: also require the neuron to sit inside the V1 outline
sig_neurons_session = (
    (neurons_df_all["iscell"] == True)
    & (neurons_df_all["is_depth_neuron"])
    & (neurons_df_all["v1"] == True)
    & (neurons_df_all["rf_sig"] == True)
)
sig_neurons_masked = sig_neurons_session & neurons_df_all["v1_mask"]
sig_neurons = sig_neurons_masked if use_v1_mask else sig_neurons_session
print(
    f"Depth-selective neurons with significant RFs:\n"
    f"  session-level `v1` flag only        : {sig_neurons_session.sum()}\n"
    f"  + inside V1 outline (`v1_mask`)     : {sig_neurons_masked.sum()}"
    f"  ({sig_neurons_session.sum() - sig_neurons_masked.sum()} removed,"
    f" {100 * (1 - sig_neurons_masked.sum() / sig_neurons_session.sum()):.1f}%)"
)

neurons_df_all["log_preferred_depth"] = np.log(
    neurons_df_all["preferred_depth_closedloop"]
)
neurons_df_all["log_preferred_depth_corrected"] = np.log(
    neurons_df_all["preferred_depth_corrected"]
)

# Jitter visual space coordinates for scatter plotting
np.random.seed(0)
neurons_df_all["rf_azi_jittered"] = neurons_df_all["rf_azi"] + np.random.uniform(
    -2, 2, neurons_df_all.shape[0]
)
neurons_df_all["rf_ele_jittered"] = neurons_df_all["rf_ele"] + np.random.uniform(
    -2, 2, neurons_df_all.shape[0]
)
neurons_df_sig = neurons_df_all[sig_neurons]

xlims = [50, overview_img.shape[1] - 50]
ylims = [50, overview_img.shape[0] - 50]
pixel_size = 6600 / (2064 / 2)  # widefield camera: 6.6 mm for 1032 pixels (2064 pixels binned 2x2)
print(f"{len(neurons_df_sig)} neurons used for the figure (use_v1_mask={use_v1_mask}).")

# %%
# Calculate smoothed Gaussian maps and visual space binned grids
xrange = int(neurons_df_all["overview_x_aligned"].min()), int(
    neurons_df_all["overview_x_aligned"].max()
)
yrange = int(neurons_df_all["overview_y_aligned"].min()), int(
    neurons_df_all["overview_y_aligned"].max()
)
xx, yy = np.mgrid[xrange[0] : xrange[1] : 10, yrange[0] : yrange[1] : 10]

length_scale = 25
x_pts = xx.ravel()
y_pts = yy.ravel()
neurons_x = neurons_df_sig["overview_x_aligned"].values[:, None]
neurons_y = neurons_df_sig["overview_y_aligned"].values[:, None]
dist_sq = (neurons_x - x_pts[None, :]) ** 2 + (neurons_y - y_pts[None, :]) ** 2
weights = np.exp(-dist_sq / length_scale**2)
alpha = np.sum(weights, axis=0)

maps = {}
maps_alpha = {}
for col in ["rf_azi", "rf_ele", "log_preferred_depth"]:
    vals = neurons_df_sig[col].values[:, None]
    zz = np.sum(weights * vals, axis=0) / alpha
    maps[col] = zz.reshape(xx.shape).T
    maps_alpha[col] = alpha.reshape(xx.shape).T

# Hierarchical bootstrap samples for preferred depth gradient
n_boot = 20000
# Flip this on its own to re-run only the bootstrap (~25 min) without the heavy
# reload in the cell above. It overwrites rf_gradient_bootstraps.pkl.
recompute_bootstraps = recompute_summary
if recompute_bootstraps:
    # Every predictor is correlated against both depth definitions: the raw
    # preferred depth and the one corrected for viewing angle / eccentricity.
    corr_cols = [
        "rf_azi",
        "rf_ele",
        "z_position",
        "overview_x_aligned",
        "overview_y_aligned",
    ]
    depth_cols = ["log_preferred_depth", "log_preferred_depth_corrected"]
    corrs = {depth_col: {col: [] for col in corr_cols} for depth_col in depth_cols}
    np.random.seed(0)
    coefs = []
    coefs_corrected = []
    for _ in tqdm(range(n_boot)):
        # Hierarchical resample: mice -> sessions within mouse -> neurons within
        # session. A flat resample over neurons would treat all neurons as
        # independent and shrink the CIs roughly fourfold.
        sample = common_utils.bootstrap_sample(
            neurons_df_all[sig_neurons], ["mouse", "session"]
        )
        # One rank pass over all columns at once, then read the predictor x
        # depth-definition block out of the resulting correlation matrix.
        rho = spearmanr(neurons_df_all.loc[sample, corr_cols + depth_cols].values)[0]
        for icol, col in enumerate(corr_cols):
            for idepth, depth_col in enumerate(depth_cols):
                corrs[depth_col][col].append(rho[icol, len(corr_cols) + idepth])
        X = neurons_df_all.loc[sample, ["rf_azi", "rf_ele"]].values
        y = neurons_df_all.loc[sample, "log_preferred_depth"].values
        reg = LinearRegression().fit(X, y)
        coefs.append(reg.coef_)

        y = neurons_df_all.loc[sample, "log_preferred_depth_corrected"].values
        reg = LinearRegression().fit(X, y)
        coefs_corrected.append(reg.coef_)

    rf_gradient_bootstraps = {
        "coefs": coefs,
        "coefs_corrected": coefs_corrected,
        "corrs": corrs,
    }
    with open(SAVE_ROOT / "rf_gradient_bootstraps.pkl", "wb") as f:
        pickle.dump(rf_gradient_bootstraps, f, protocol=pickle.HIGHEST_PROTOCOL)
else:
    with open(READ_ROOT / "rf_gradient_bootstraps.pkl", "rb") as f:
        rf_gradient_bootstraps = pickle.load(f)
    coefs = np.array(rf_gradient_bootstraps["coefs"])
    coefs_corrected = np.array(rf_gradient_bootstraps["coefs_corrected"])
    corrs = rf_gradient_bootstraps["corrs"]
    if not isinstance(next(iter(corrs.values())), dict):
        # Cache written before the corrected depth was bootstrapped: it holds a
        # flat {predictor: samples} dict for the raw depth only.
        corrs = {"log_preferred_depth": corrs}

# 2D visual space grids for Panels E and F
xrange_vs = 17.5, 117.5
yrange_vs = -37.5, 37.5
xx_vs, yy_vs = np.mgrid[xrange_vs[0] : xrange_vs[1] + 5 : 5, yrange_vs[0] : yrange_vs[1] + 5 : 5]
im_extent = (xrange_vs[0] - 2.5, xrange_vs[1] + 2.5, yrange_vs[0] - 2.5, yrange_vs[1] + 2.5)

this_col = "preferred_depth_corrected"
median_depth = np.ravel(np.zeros(xx_vs.shape))
for i, (x, y) in enumerate(zip(np.ravel(xx_vs), np.ravel(yy_vs))):
    idx = (neurons_df_sig["rf_azi"] == x) & (neurons_df_sig["rf_ele"] == y)
    if np.sum(idx) < 20:
        median_depth[i] = np.nan
    else:
        median_depth[i] = np.median(neurons_df_sig[idx][this_col])
median_depth = np.reshape(median_depth, xx_vs.shape).T

def calculate_zz(condition):
    zz = np.ravel(np.zeros(xx_vs.shape))
    for i, (x, y) in enumerate(zip(np.ravel(xx_vs), np.ravel(yy_vs))):
        idx = (neurons_df_sig["rf_azi"] == x) & (neurons_df_sig["rf_ele"] == y)
        if np.sum(idx) < 20:
            zz[i] = np.nan
        else:
            zz[i] = np.mean(condition[idx])
    return np.reshape(zz, xx_vs.shape).T

# %% [markdown]
# ## 2. Publication Figure 5: Depth Representation Across V1 & Visual Space

# %%
# Assemble unified Figure 5 canvas (Panels A-F)
fig = plt.figure(figsize=(v1_map.FIG_W / CM, v1_map.FIG_H / CM), dpi=300)
v1_map.assemble_figure_5(
    fig=fig,
    overview_img=overview_img,
    neurons_df_sig=neurons_df_sig,
    maps=maps,
    maps_alpha=maps_alpha,
    xrange=xrange,
    yrange=yrange,
    xlims=xlims,
    ylims=ylims,
    median_depth=median_depth,
    coefs_corrected=coefs_corrected,
    im_extent=im_extent,
    calculate_zz_func=calculate_zz,
    pixel_size=pixel_size,
)

save_path = SAVE_ROOT / "fig5.svg"
style.savefig(save_path, fig=fig, dpi=300, bbox_inches="tight")
print(f"Figure 5 successfully saved to: {save_path}")
plt.show()

# %% [markdown]
# ## 3. Statistical Analysis

# %%
# Statistical test for gradient significance across visual space
p_val_corrected = ztest_2d(coefs_corrected)[0]
p_val_uncorrected = ztest_2d(coefs)[0]
print(f"P-value for gradient for corrected depth: {p_val_corrected:.2e}")
print(f"P-value for gradient for uncorrected depth: {p_val_uncorrected:.5f}")

# Spearman correlation with AP and ML coordinates in V1
for colx in ["overview_x_aligned", "overview_y_aligned"]:
    for coly in ["log_preferred_depth", "log_preferred_depth_corrected"]:
        r, p = spearmanr(neurons_df_sig[colx], neurons_df_sig[coly])
        print(f"Correlation R {colx} vs {coly}: r = {r:.3f}, p = {p:.4e}")

# %%
# Bootstrap correlation distributions across cortical axes and RF coordinates,
# for both the raw and the eccentricity-corrected preferred depth
depth_cols_plot = list(corrs)
corr_cols_plot = list(corrs[depth_cols_plot[0]])
fig, axes = plt.subplots(
    len(depth_cols_plot),
    len(corr_cols_plot),
    figsize=(3 * len(corr_cols_plot), 3.2 * len(depth_cols_plot)),
    squeeze=False,
)
for irow, depth_col in enumerate(depth_cols_plot):
    print(f"--- {depth_col} ---")
    for icol, col in enumerate(corr_cols_plot):
        r = np.asarray(corrs[depth_col][col])
        lo, hi = np.quantile(r, [0.025, 0.975])
        p = 2 * min(np.mean(r > 0), np.mean(r <= 0))
        ax = axes[irow, icol]
        ax.hist(r, bins=20, color="k")
        ax.axvline(lo, c="r")
        ax.axvline(hi, c="r")
        ax.axvline(0, color="k", linestyle="--")
        ax.set_title(f"{col}\np = {p:.3f}", fontsize=FONTSIZE_DICT["title"])
        print(f"{col}: r = {np.median(r):+.3f} [{lo:+.3f}, {hi:+.3f}], p = {p:.4e}")
    axes[irow, 0].set_ylabel(depth_col, fontsize=FONTSIZE_DICT["label"])
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Optional & Diagnostic Plots

# %%
# Retinotopic depth correction factor across visual space
xrange_corr = 27.5, 117.5
yrange_corr = -37.5, 37.5
xx_c, yy_c = np.mgrid[xrange_corr[0] : xrange_corr[1] + 5 : 5, yrange_corr[0] : yrange_corr[1] + 5 : 5]
im_extent_corr = (xrange_corr[0] - 2.5, xrange_corr[1] + 2.5, yrange_corr[0] - 2.5, yrange_corr[1] + 2.5)

correction = np.log2(
    1
    / np.sqrt(
        (np.sin(np.deg2rad(xx_c)) ** 2) * (np.cos(np.deg2rad(yy_c)) ** 2)
        + (np.sin(np.deg2rad(yy_c)) ** 2)
    )
)

fig, ax = plt.subplots(figsize=(6, 4))
im = ax.imshow(correction.T, extent=im_extent_corr, origin="lower", cmap="viridis")
ax.set_xlabel("RF azimuth (degrees)", fontsize=FONTSIZE_DICT["label"])
ax.set_ylabel("RF elevation (degrees)", fontsize=FONTSIZE_DICT["label"])
cbar = plt.colorbar(im, ax=ax)
cbar.set_label(r"Correction factor ($\log_2$ distance ratio)", fontsize=FONTSIZE_DICT["label"])
cbar.ax.tick_params(labelsize=FONTSIZE_DICT["tick"])
ax.tick_params(labelsize=FONTSIZE_DICT["tick"])
ax.set_title("Spherical Stimulus Distance Adjustment Across Visual Space", fontsize=FONTSIZE_DICT["title"])
plt.show()
