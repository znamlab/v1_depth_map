# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42 # for pdfs
matplotlib.rcParams['svg.fonttype'] = 'none' # for svgs
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
import matplotlib.pyplot as plt
import flexiznam as flz
from cottage_analysis.analysis import spheres
from cottage_analysis.pipelines import pipeline_utils
from cottage_analysis.summary_analysis import depth_responses, summary_utils, get_session_list, depth_decoder_stats
from cottage_analysis.plotting import depth_selectivity_plots, depth_decoder_plots, plotting_utils

# %%
matplotlib.rcParams['axes.labelpad'] = 1      # x and y axis labels (default 4.0)
matplotlib.rcParams['xtick.major.pad'] = 1    # default 3.5
matplotlib.rcParams['ytick.major.pad'] = 1
matplotlib.rcParams['xtick.minor.pad'] = 1    # default 3.4
matplotlib.rcParams['ytick.minor.pad'] = 1

# %%
np.arange(514, 568, 15)

# %%
project = "hey2_3d-vision_foodres_20220101"
flexilims_session = flz.get_flexilims_session(project)
from v1_depth_map.paths import get_figures_roots

READ_ROOT, SAVE_ROOT = get_figures_roots(flexilims_session)

SAVE_ROOT.mkdir(parents=True, exist_ok=True)
(SAVE_ROOT / "fig1").mkdir(parents=True, exist_ok=True)

recompute_summary = False  # True: rebuild neurons_df_all/results_all from per-session pickles and re-cache; False: load the cached combined pickle
print(f"Saving output to {SAVE_ROOT}")
if READ_ROOT != SAVE_ROOT:
    print(f"Reading data from {READ_ROOT}")

# %%
# Load data
# Load an example session
project = "hey2_3d-vision_foodres_20220101"
session_name = "PZAH8.2h_S20230116"
flexilims_session = flz.get_flexilims_session(project)

vs_df_example, trials_df_example = spheres.sync_all_recordings(
    session_name=session_name,
    flexilims_session=flexilims_session,
    project=project,
    filter_datasets={"anatomical_only": 3, "ast_neuropil": False},
    recording_type="two_photon",
    protocol_base="SpheresPermTubeReward",
    photodiode_protocol=5,
    return_volumes=True,
)
suite2p_ds = flz.get_datasets_recursively(
    flexilims_session=flexilims_session,
    origin_name=session_name,
    dataset_type="suite2p_traces",
)
fs = list(suite2p_ds.values())[0][-1].extra_attributes["fs"]

neurons_ds_example = pipeline_utils.create_neurons_ds(
    session_name=session_name,
    flexilims_session=flexilims_session,
    project=None,
    conflicts="skip",
)
neurons_df_example = pd.read_pickle(neurons_ds_example.path_full)

suite2p_ds = flz.get_datasets(
    flexilims_session=flexilims_session,
    origin_name=session_name,
    dataset_type="suite2p_rois",
    filter_datasets={"anatomical_only": 3},
    allow_multiple=False,
    return_dataseries=False,
)
stat = np.load(suite2p_ds.path_full / "plane0" / "stat.npy", allow_pickle=True)
iscell = np.load(suite2p_ds.path_full / "plane0" / "iscell.npy", allow_pickle=True)[
    :, 0
]
ops = np.load(suite2p_ds.path_full / "plane0" / "ops.npy", allow_pickle=True).item()

# %%
# Concatenate neurons_df from all closedloop sessions (including sessions with openloop)
mouse_list = flz.get_entities("mouse", flexilims_session=flexilims_session)
mouse_list = mouse_list[
    mouse_list.name.isin(
        [
            "PZAH6.4b",
            "PZAG3.4f",
            "PZAH8.2h",
            "PZAH8.2i",
            "PZAH8.2f",
            "PZAH10.2d",
            "PZAH10.2f",
        ]
    )
]
if recompute_summary:
    neurons_df_all = summary_utils.concatenate_all_neurons_df(
        flexilims_session=flexilims_session,
        session_list=get_session_list.get_sessions(
            flexilims_session,
            exclude_openloop=False,
            exclude_pure_closedloop=False,
            v1_only=True,
            trialnum_min=10,
            mouse_list=mouse_list,
        ),
        filename="neurons_df.pickle",
        cols=[
            "roi",
            "is_depth_neuron",
            "depth_neuron_anova_p",
            "best_depth",
            "preferred_depth_closedloop",
            "depth_tuning_popt_closedloop",
            "depth_tuning_trials_closedloop_crossval",
            "preferred_depth_closedloop_crossval",
            "depth_tuning_popt_closedloop_running",
            "preferred_depth_closedloop_running",
            "depth_tuning_popt_closedloop_notrunning",
            "preferred_depth_closedloop_notrunning",
            "depth_tuning_test_rsq_closedloop",
            "depth_tuning_test_spearmanr_rval_closedloop",
            "depth_tuning_test_spearmanr_pval_closedloop",
        ],
        read_iscell=True,
        verbose=True,
    )
    neurons_df_all.to_pickle(SAVE_ROOT / "fig1/neurons_df_all.pickle")
else:
    neurons_df_all = pd.read_pickle(READ_ROOT / "fig1/neurons_df_all.pickle")
neurons_df_all = neurons_df_all[neurons_df_all["iscell"] == 1]

# Load the depth tuning raster. To recompute, use make_depth_tuning_raster.py
if recompute_summary:
    results_all = depth_responses.get_psth_crossval_all_sessions(
        flexilims_session,
        session_list=get_session_list.get_sessions(
            flexilims_session,
            exclude_openloop=False,
            exclude_pure_closedloop=False,
            v1_only=True,
            trialnum_min=10,
            mouse_list=mouse_list,
        ),
        nbins=60,
        closed_loop=1,
        use_cols=[
            "roi",
            "is_depth_neuron",
            "depth_neuron_anova_p",
            "best_depth",
            "preferred_depth_closedloop",
            "depth_tuning_popt_closedloop",
            "depth_tuning_trials_closedloop",
            "depth_tuning_trials_closedloop_crossval",
            "preferred_depth_closedloop_crossval",
            "depth_tuning_test_rsq_closedloop",
            "depth_tuning_test_spearmanr_rval_closedloop",
            "depth_tuning_test_spearmanr_pval_closedloop",
        ],
        blank_length=3,
        overwrite=False,
    )
    results_all.to_pickle(SAVE_ROOT / "fig1/results_all_psth.pickle")
else:
    results_all = pd.read_pickle(READ_ROOT / "fig1/results_all_psth.pickle")

# print some stats
print(
    f"5 depth sessions: {len(results_all[results_all.session.str.contains('PZAH6.4b|PZAG3.4f')].session.unique())}"
)
print(
    f"8 depth sessions: {len(results_all[~results_all.session.str.contains('PZAH6.4b|PZAG3.4f')].session.unique())}"
)
print(f"Total depth sessions: {len(neurons_df_all.session.unique())}")
print(f"All neurons: {len(neurons_df_all)}")
print(
    f"Depth neurons: {((neurons_df_all['depth_tuning_test_spearmanr_rval_closedloop'] > 0.1) & (neurons_df_all['depth_tuning_test_spearmanr_pval_closedloop'] < 0.05)).sum()}"
)
print(
    f"Mean proportion of depth neurons {((neurons_df_all['depth_tuning_test_spearmanr_rval_closedloop'] > 0.1) & (neurons_df_all['depth_tuning_test_spearmanr_pval_closedloop'] < 0.05)).mean()}"
)

# %%
# Load depth decoder results from all closedloop sessions (including sessions with openloop)
mouse_list = flz.get_entities("mouse", flexilims_session=flexilims_session)
mouse_list = mouse_list[
    mouse_list.name.isin(
        [
            "PZAH6.4b",
            "PZAG3.4f",
            "PZAH8.2h",
            "PZAH8.2i",
            "PZAH8.2f",
            "PZAH10.2d",
            "PZAH10.2f",
        ]
    )
]


if recompute_summary:
    decoder_df = summary_utils.concatenate_all_neurons_df(
        flexilims_session,
        session_list=get_session_list.get_sessions(
            flexilims_session,
            exclude_openloop=False,
            exclude_pure_closedloop=False,
            v1_only=True,
            trialnum_min=10,
            mouse_list=mouse_list,
        ),
        filename="decoder_results.pickle",
        cols=[
            "accuracy_closedloop",
            "conmat_closedloop",
            "best_C_closedloop",
            "acc_speed_bins_closedloop",
            "conmat_speed_bins_closedloop",
        ],
        read_iscell=False,
        verbose=True,
    )

    decoder_df.to_pickle(SAVE_ROOT / "decoder_df_all.pickle")
else:
    decoder_df = pd.read_pickle(READ_ROOT / "decoder_df_all.pickle")
print(
    f"Total depth decoder sessions: {len(decoder_df.session.unique())}"
)  # should be the same as the session number above

# %%
# Load data for the multi-day tracking summary panels (from figsupp_multidays.ipynb),
# which are embedded into fig_4ex below.
import json
from pathlib import Path
import seaborn as sns
from scipy.stats import spearmanr
from v1_depth_map.revisions.revision_sessions import sessions

multiday_project = "colasa_3d-vision_revisions"
flexilims_session_multiday = flz.get_flexilims_session(multiday_project)

sphere_sessions = [(k, v) for k, v in sessions.items() if ("sphere" in v)]
mice_multiday = set([sess[0].split("_")[0] for sess in sphere_sessions])

neurons_dfs_multiday = dict()
for sess_name, protocol in sphere_sessions:
    mouse, sess = sess_name.split("_")
    ndf = pd.read_pickle(
        flz.get_processed_path(multiday_project) / mouse / sess / "neurons_df.pickle"
    )
    ndf["mouse"] = mouse
    ndf["session"] = sess_name
    ndf["uid"] = ndf.session.astype(str) + "_" + (ndf.roi).astype(str)
    ndf["day"] = int(protocol.split("_")[1])
    neurons_dfs_multiday[sess_name] = ndf
neurons_df_multiday = pd.concat(neurons_dfs_multiday.values(), ignore_index=True)

neurons_df_multiday["depth_tuned"] = neurons_df_multiday.apply(
    lambda x: x["depth_tuning_test_spearmanr_rval_closedloop"] > 0.1
    and x["depth_tuning_test_spearmanr_pval_closedloop"] < 0.05,
    axis=1,
)
# Day 1 of PZAH17.1e crashed and sync between vis stim and recording is broken
to_remove = neurons_df_multiday[
    (neurons_df_multiday.mouse == "PZAH17.1e") & (neurons_df_multiday.day == 1)
].index
neurons_df_multiday = neurons_df_multiday.drop(index=to_remove)

# Proportion of depth-tuned neurons per mouse, per day
all_frac = []
for mouse, mouse_df in neurons_df_multiday.groupby("mouse"):
    frac = np.zeros(5, dtype=float) + np.nan
    for day, day_df in mouse_df.groupby("day"):
        valid = day_df[~np.isnan(day_df.depth_tuned)]
        frac[day - 1] = valid.depth_tuned.sum() / len(valid.depth_tuned)
    all_frac.append(frac)
fractions_depth_by_day = np.vstack(all_frac)

# Load manual (ROICat click-based) cross-day tracking IDs
root_path_multiday = str(flz.get_processed_path(multiday_project))
neurons_df_multiday["tracking_id_manual"] = np.nan
neurons_df_multiday["tracking_uid_manual"] = ""

for mouse in mice_multiday:
    roicat_path = "/".join(
        [
            root_path_multiday,
            mouse,
            "ROICat_spheretubes",
            f"{mouse}_roicat.tracking.params_used.json",
        ]
    )
    with open(roicat_path) as roicat_file:
        roicat_params = json.load(roicat_file)
    session_list = []
    for statfile in roicat_params["data"]["__init__"]["paths_statFiles"]:
        session_list.append(statfile.split(mouse)[1].split("/")[1])

    manual_click = Path(
        "/".join([root_path_multiday, mouse, "ROICat_spheretubes", "matches.json"])
    )
    if manual_click.exists():
        with open(manual_click, "r") as f:
            matches = json.load(f)
        matches = np.array(matches, dtype=float)
    else:
        matches = None
        continue

    for sess_id, sess in enumerate(session_list):
        sess_name = f"{mouse}_{sess}"
        manual_ids = np.arange(matches.shape[0])
        valid = ~np.isnan(matches[:, sess_id])

        valid_rois = (matches[valid, sess_id].astype(int) - 1).astype(str)
        neuron_uids = [sess_name + "_" + roi for roi in valid_rois]
        valid_manual_ids = manual_ids[valid]
        uid_to_manual_id = dict(zip(neuron_uids, valid_manual_ids))

        mask_sess = neurons_df_multiday.session == sess_name
        neurons_df_multiday.loc[mask_sess, "tracking_id_manual"] = (
            neurons_df_multiday.loc[mask_sess, "uid"].map(uid_to_manual_id)
        )

neurons_df_multiday["tracking_id_manual"] = np.nan_to_num(
    neurons_df_multiday["tracking_id_manual"], nan=-1
)
mask = neurons_df_multiday.tracking_id_manual != -1
neurons_df_multiday.loc[mask, "tracking_uid_manual"] = neurons_df_multiday.loc[
    mask, "mouse"
] + neurons_df_multiday.loc[mask, "tracking_id_manual"].astype(int).astype(str)

# Cache for trials_df to avoid reloading for every example neuron/day
trials_df_cache_multiday = {}


def get_amp(popt):
    return (
        np.exp(popt[0])
        if (isinstance(popt, (list, np.ndarray)) and len(popt) > 0)
        else 0
    )


neurons_df_multiday["fit_amp"] = neurons_df_multiday[
    "depth_tuning_popt_closedloop_running"
].apply(get_amp)

# Select tracked neurons with a well-fit tuning curve, present on all 5 days
tracked_multiday = neurons_df_multiday[
    (neurons_df_multiday.tracking_uid_manual != "")
    & (neurons_df_multiday.fit_amp >= 0.4)
]
day_counts = tracked_multiday.groupby("tracking_uid_manual")["day"].nunique()
full_track_ids = day_counts[day_counts == 5].index.tolist()
np.random.seed(45)
example_tids_multiday = (
    full_track_ids  # np.random.choice(full_track_ids, size=11, replace=False)
)
avg_depths_multiday = tracked_multiday.groupby("tracking_uid_manual")[
    "preferred_depth_closedloop_running"
].mean()
example_tids_multiday = (
    avg_depths_multiday.loc[example_tids_multiday].sort_values().index
)
example_tids_multiday = (example_tids_multiday[[1, 2, 8, 10]]).tolist()

# Match the fontsize used by the rest of fig_4ex's panels
fontsize_dict_multiday = {"title": 7, "label": 7, "tick": 5, "legend": 5}
depth_tuning_kwargs_multiday = dict(
    plot_fit=True,
    plot_smooth=False,
    linewidth=1.5,
    closed_loop=1,
    fontsize_dict=fontsize_dict_multiday,
    markersize=6,
    markeredgecolor="w",
)

# %%
# Plot Fig.1
fontsize_dict = {"title": 7, "label": 7, "tick": 5, "legend": 5}
cm = 1 / 2.54
# Raster plot of an example neuron
EXAMPLE_ROI = 250
fig = plt.figure(figsize=(18 * cm, 18 * cm))
_, ax = depth_selectivity_plots.plot_raster_all_depths(
    trials_df=trials_df_example,
    roi=EXAMPLE_ROI,
    is_closed_loop=True,
    corridor_length=6,
    blank_length=3,
    nbins=60,
    vmax=3,
    plot=True,
    cbar_width=0.01,
    fontsize_dict=fontsize_dict,
    position=[0.05, 0.75, 0.3, 0.15],
)
plotting_utils.draw_axis_scalebars(
    ax=fig.add_axes([0, 0, 1, 1]),
    scalebar_x=0.059,
    scalebar_y=0.91,
    scalebar_width=0.02,
    scalebar_height=0.05,
    scalebar_labels=["6 m of travel", ""],
    xlim=None,
    ylim=None,
    label_fontsize=5,
    linewidth=2,
    right=False,
    bottom=True,
)

# Example running & PSTH of a single neuron
ax = fig.add_axes([0.51, 0.81, 0.18, 0.1])
depth_selectivity_plots.plot_PSTH(
    trials_df=trials_df_example,
    roi=EXAMPLE_ROI,
    is_closed_loop=True,
    use_col="dff",
    corridor_length=6,
    blank_length=3,
    nbins=60,
    frame_rate=fs,
    fontsize_dict=fontsize_dict,
    linewidth=1,
    legend_on=True,
    show_ci=False,
    ylim=(None, 1.3),
)
ax.set_yticks([0, 1.3])
ax.set_xticks([])
ax.set_xlabel("")

ax = fig.add_axes([0.51, 0.75, 0.18, 0.05])
depth_selectivity_plots.plot_PSTH(
    trials_df=trials_df_example,
    roi=EXAMPLE_ROI,
    is_closed_loop=True,
    use_col="RS",
    corridor_length=6,
    blank_length=3,
    nbins=60,
    frame_rate=fs,
    fontsize_dict=fontsize_dict,
    linewidth=1,
    legend_on=False,
    show_ci=False,
    ylim=(0, 115),
)
ax.set_ylabel("Running \nspeed (cm/s)", fontsize=fontsize_dict["label"])

# Example depth tuning curve & PSTH of a single neuron
ax = fig.add_axes([0.8, 0.75, 0.15, 0.15])
depth_tuning_kwargs = dict(
    rs_thr=None,
    plot_fit=True,
    plot_smooth=False,
    linewidth=2,
    linecolor="royalblue",
    closed_loop=1,
    fontsize_dict=fontsize_dict,
    markersize=10,
    markeredgecolor="w",
)
depth_selectivity_plots.plot_running_stationary_depth_tuning(
    roi=EXAMPLE_ROI,
    roi_num=1,
    i=0,
    ax=ax,
    neurons_df=neurons_df_example,
    trials_df=trials_df_example,
    depth_tuning_kwargs=depth_tuning_kwargs,
    fontsize_dict=fontsize_dict,
    legend_loc="upper left",
)
ax.set_ylabel("ΔF/F", fontsize=fontsize_dict["label"])
ax.set_xlabel("Virtual depth (cm)", fontsize=fontsize_dict["label"])

# Example depth tuning curve of 6 other neuronsn (running vs not running)
EXAMPLE_ROIS = [174, 249, 319, 638, 333, 696]

neurons_df_example["depth_tuned"] = neurons_df_example.apply(
    lambda x: x["depth_tuning_test_spearmanr_rval_closedloop"] > 0.1
    and x["depth_tuning_test_spearmanr_pval_closedloop"] < 0.05,
    axis=1,
)

overlay = np.zeros((ops["meanImg"].shape[0], ops["meanImg"].shape[1], 4))
for i, roi in enumerate(stat):
    if iscell[i]:
        overlay[roi["ypix"], roi["xpix"]] = [0, 1, 1, 0.25]
    # if i in EXAMPLE_ROIS or i == EXAMPLE_ROI:
    #     overlay[roi["ypix"], roi["xpix"]] = [1, 0, 0, 0.75]
    if neurons_df_example["depth_tuned"].iloc[i]:
        overlay[roi["ypix"], roi["xpix"]] = [1, 0, 0, 0.75]

fov_ax = fig.add_axes([0.35, 0.25, 0.48, 0.48])
depth_selectivity_plots.plot_fov_mean_img(ops["meanImg"], fov_width=661)
plt.imshow(np.fliplr(overlay))
fov_ax.annotate(
    "1",
    (
        ops["meanImg"].shape[0] - stat[EXAMPLE_ROI]["med"][1],
        stat[EXAMPLE_ROI]["med"][0],
    ),
    xytext=(5, 5),
    textcoords="offset points",
    color="w",
    fontsize=fontsize_dict["label"],
    arrowprops=dict(facecolor="w", edgecolor="w", arrowstyle="->"),
)
from matplotlib.lines import Line2D

legend_elements = [
    Line2D(
        [0],
        [0],
        marker="o",
        markersize=3,
        linestyle="none",
        color="cyan",
        label="All neurons",
    ),
    Line2D(
        [0],
        [0],
        marker="o",
        markersize=3,
        linestyle="none",
        color="red",
        label="Depth-tuned neurons",
    ),
]
fov_ax.legend(
    handles=legend_elements,
    loc="upper right",
    fontsize=fontsize_dict["label"],
    frameon=True,
    framealpha=0.8,
    borderpad=0.6,
)

depth_tuning_kwargs = dict(
    rs_thr=None,
    plot_fit=True,
    plot_smooth=False,
    linewidth=1.5,
    linecolor="royalblue",
    closed_loop=1,
    fontsize_dict=fontsize_dict,
    markersize=8,
    markeredgecolor="w",
)
for i, roi in enumerate(EXAMPLE_ROIS):
    ax = fig.add_axes([i // 3 * 0.16 + 0.06, 0.57 - i % 3 * 0.13, 0.11, 0.1])
    if i < 3:
        label_pos = "upper_right"
    else:
        label_pos = "upper_left"

    roi_num = i + 2
    depth_selectivity_plots.plot_running_stationary_depth_tuning(
        roi=roi,
        roi_num=roi_num,
        i=i,
        neurons_df=neurons_df_example,
        trials_df=trials_df_example,
        ax=ax,
        fov_ax=fov_ax,
        ops=ops,
        stat=stat,
        depth_tuning_kwargs=depth_tuning_kwargs,
        fontsize_dict=fontsize_dict,
        legend_loc="upper right",
        text_pos=label_pos,
    )

# Histogram of preferred depths of all depth-tuned neurons;
neurons_df_all["depth_tuned"] = neurons_df_all.apply(
    lambda x: x["depth_tuning_test_spearmanr_rval_closedloop"] > 0.1
    and x["depth_tuning_test_spearmanr_pval_closedloop"] < 0.05,
    axis=1,
)

fig.add_axes([0.8, 0.54, 0.16, 0.13])
depth_selectivity_plots.plot_preferred_depth_hist(
    results_df=neurons_df_all[(neurons_df_all["depth_tuned"] == 1)],
    use_col="preferred_depth_closedloop",
    nbins=20,
    fontsize_dict=fontsize_dict,
)

# Raster plot of preferred depths of all neurons (sorted by preferred depth), placed
# in the white space below the preferred-depth histogram
results_all["ndepths"] = results_all["psth_crossval"].apply(lambda x: len(x) - 1)
neurons_resp = results_all[
    (results_all["ndepths"] == 8)
    & (results_all["depth_tuning_test_spearmanr_rval_closedloop"] > 0.1)
    & (results_all["depth_tuning_test_spearmanr_pval_closedloop"] < 0.05)
    & (results_all["iscell"] == 1)
]
fig.add_axes([0.8, 0.22, 0.16, 0.30])
depth_selectivity_plots.plot_psth_raster(
    results_df=neurons_resp,
    depth_list=np.round(np.geomspace(5, 640, num=8)).astype(int),
    fontsize_dict=fontsize_dict,
)
plotting_utils.draw_axis_scalebars(
    ax=fig.add_axes([0, 0, 1, 1]),
    scalebar_x=0.803,
    scalebar_y=0.525,
    scalebar_width=0.16 * 0.09,
    scalebar_height=0.05,
    scalebar_labels=["6 m of travel", ""],
    xlim=None,
    ylim=None,
    label_fontsize=5,
    linewidth=2,
    right=False,
    bottom=True,
)

# Plot decoder error for different running speed bins
decoder_df = depth_decoder_stats.calculate_error_all_sessions(decoder_df)
ax1 = fig.add_axes([0.39, 0.06, 0.03, 0.15])
ax2 = fig.add_axes([0.43, 0.06, 0.14, 0.15])
_ = depth_decoder_plots.plot_decoder_err_by_speeds(
    decoder_df,
    np.insert(np.linspace(0.2, 2, 10), 0, 0.05),
    axes=[ax1, ax2],
    closed_loop=1,
    linecolor="k",
    linecolor_chance="k",
    linewidth=1,
    linewidth_chance=0.5,
    alpha=1,
    alpha_chance=1,
    markersize=5,
    fontsize_dict=fontsize_dict,
)
ax1.set_ylim([0, 3])
ax2.set_ylim([0, 3])

# Plot confusion  matrix for stationary & best running speed bin
ndepths = 8
decoder_df_8d = decoder_df[
    (decoder_df.apply(lambda x: len(x["conmat_closedloop"]) == ndepths, axis=1))
]
print(f"8 depth decoder sessions {len(decoder_df.session.unique())}")
conmats = []
for ibin in [0, 3]:
    conmat_mean = depth_decoder_plots.calculate_average_confusion_matrix(
        decoder_df_8d,
        col=f"conmat_speed_bins_closedloop_{ibin}",
        recording_types=["closedloop"],
    )
    conmat_closed = conmat_mean["closedloop"]
    conmat_closed = conmat_closed / conmat_closed.sum(axis=1)[:, np.newaxis]
    if ibin == 3:
        vmax = conmat_closed.max()
    conmats.append(conmat_closed)
vmax = np.round(vmax, 1)

if len(conmat_closed) == 8:
    depths = np.logspace(np.log2(5), np.log2(640), 8, base=2)
else:
    depths = np.logspace(np.log2(6), np.log2(600), 5, base=2)
depths = np.round(depths).astype(int)

for iplot, (title, colorbar_on) in enumerate(
    zip(["Stationary", "Running speed 40 - 60 cm/s"], [0, 1])
):
    ax = fig.add_axes([0.655 + 0.17 * iplot, 0.06, 0.13, 0.13])
    depth_decoder_plots.plot_confusion_matrix(
        conmats[iplot],
        ax,
        vmax,
        fontsize_dict,
        depths=depths,
        colorbar_on=colorbar_on,
        xtick_rotation=45,
    )
    ax.set_title(title, fontsize=fontsize_dict["title"])
    if iplot == 1:
        ax.set_xlabel("")
        ax.set_ylabel("")


fig.savefig(SAVE_ROOT / "fig1.svg", bbox_inches="tight", dpi=300)

# %%
# Plot Fig.1 - alternative version with only 2 example cells (3, 5) instead of 6,
# side by side, with the preferred-depth histogram moved below them and the multi-day
# tracked-cell grid moved into the freed space to the right of the FOV.
fig_4ex = plt.figure(figsize=(18 * cm, 18 * cm))
ax_null = fig.add_axes([0, 0, 1, 1])
ax_null.set_xticks([])
ax_null.set_yticks([])

_, ax_raster = depth_selectivity_plots.plot_raster_all_depths(
    trials_df=trials_df_example,
    roi=EXAMPLE_ROI,
    is_closed_loop=True,
    corridor_length=6,
    blank_length=3,
    nbins=60,
    vmax=3,
    plot=True,
    cbar_width=0.01,
    fontsize_dict=fontsize_dict,
    position=(0.05, 0.75, 0.3, 0.15),
)
CORRIDOR_M = 6.0      # metres of virtual corridor per depth block
BLANK_WINDOW_M = 3.0  # blank_length: the *analysis window* either side (sets bin edges)
NBINS_FULL = 60       # nbins; plot_raster_all_depths plots all of them (no trimming)
m_per_bin = (CORRIDOR_M + 2 * BLANK_WINDOW_M) / NBINS_FULL      # 0.2 m
# imshow pixel j spans j +/- 0.5, so 0 m is the *edge* below bin 15
x0 = BLANK_WINDOW_M / m_per_bin - 0.5                           # 14.5 -> 0 m
x1 = x0 + CORRIDOR_M / m_per_bin                                # 44.5 -> 6 m
assert np.isclose((x1 - x0) * m_per_bin, CORRIDOR_M)
y_bar = 1.03                                                    # just above the raster
ax_raster.plot(
    [x0, x1], [y_bar, y_bar],
    transform=ax_raster.get_xaxis_transform(), color="k", linewidth=2,
    solid_capstyle="butt", clip_on=False,
)
ax_raster.text(
    (x0 + x1) / 2, y_bar + 0.03, f"{CORRIDOR_M:g} m of travel",
    transform=ax_raster.get_xaxis_transform(), ha="center", va="bottom",
    fontsize=fontsize_dict["legend"],
)

# Example running & PSTH of a single neuron
if True:
    ax = fig_4ex.add_axes((0.50, 0.81, 0.18, 0.1))
    depth_selectivity_plots.plot_PSTH(
        trials_df=trials_df_example,
        roi=EXAMPLE_ROI,
        is_closed_loop=True,
        use_col="dff",
        corridor_length=6,
        blank_length=3,
        nbins=60,
        frame_rate=fs,
        fontsize_dict=fontsize_dict,
        linewidth=1,
        legend_on=True,
        show_ci=False,
        ylim=(None, 1.3),
    )
    ax.set_yticks([0, 1.3])
    ax.set_xticks([])
    ax.set_xlabel("")

    ax = fig_4ex.add_axes((0.50, 0.75, 0.18, 0.05))
    depth_selectivity_plots.plot_PSTH(
        trials_df=trials_df_example,
        roi=EXAMPLE_ROI,
        is_closed_loop=True,
        use_col="RS",
        corridor_length=6,
        blank_length=3,
        nbins=60,
        frame_rate=fs,
        fontsize_dict=fontsize_dict,
        linewidth=1,
        legend_on=False,
        show_ci=False,
        ylim=(0, 115),
    )
    ax.set_ylabel("Running \nspeed (cm/s)", fontsize=fontsize_dict["label"])

# Example depth tuning curve & PSTH of a single neuron
if True:
    ax = fig_4ex.add_axes((0.8, 0.75, 0.15, 0.15))
    depth_tuning_kwargs = dict(
        rs_thr=None,
        plot_fit=True,
        plot_smooth=False,
        linewidth=2,
        linecolor="royalblue",
        closed_loop=1,
        fontsize_dict=fontsize_dict,
        markersize=10,
        markeredgecolor="w",
    )
    depth_selectivity_plots.plot_running_stationary_depth_tuning(
        roi=EXAMPLE_ROI,
        roi_num=1,
        i=0,
        ax=ax,
        neurons_df=neurons_df_example,
        trials_df=trials_df_example,
        depth_tuning_kwargs=depth_tuning_kwargs,
        fontsize_dict=fontsize_dict,
        legend_loc="upper left",
    )
    ax.set_ylabel("ΔF/F", fontsize=fontsize_dict["label"])
    ax.set_xlabel("Virtual depth (cm)", fontsize=fontsize_dict["label"])

# FOV
if True:
    neurons_df_example["depth_tuned"] = neurons_df_example.apply(
        lambda x: x["depth_tuning_test_spearmanr_rval_closedloop"] > 0.1
        and x["depth_tuning_test_spearmanr_pval_closedloop"] < 0.05,
        axis=1,
    )

    overlay = np.zeros((ops["meanImg"].shape[0], ops["meanImg"].shape[1], 4))
    for i, roi in enumerate(stat):
        if iscell[i]:
            overlay[roi["ypix"], roi["xpix"]] = [0, 1, 1, 0.25]
        if neurons_df_example["depth_tuned"].iloc[i]:
            overlay[roi["ypix"], roi["xpix"]] = [1, 0, 0, 0.75]

    fov_ax = fig_4ex.add_axes((0.33, 0.41, 0.33, 0.27))
    depth_selectivity_plots.plot_fov_mean_img(ops["meanImg"], fov_width=661)
    plt.imshow(np.fliplr(overlay))
    fov_ax.annotate(
        "1",
        (
            ops["meanImg"].shape[0] - stat[EXAMPLE_ROI]["med"][1],
            stat[EXAMPLE_ROI]["med"][0],
        ),
        xytext=(5, 5),
        textcoords="offset points",
        color="w",
        fontsize=fontsize_dict["label"],
        arrowprops=dict(facecolor="w", edgecolor="w", arrowstyle="->"),
    )
    from matplotlib.lines import Line2D

    legend_elements = [
        Line2D(
            [0],
            [0],
            marker="o",
            markersize=3,
            linestyle="none",
            color="cyan",
            label="All neurons",
        ),
        Line2D(
            [0],
            [0],
            marker="o",
            markersize=3,
            linestyle="none",
            color="red",
            label="Depth-tuned neurons",
        ),
    ]
    fov_ax.legend(
        handles=legend_elements,
        loc="upper right",
        fontsize=fontsize_dict["label"],
        frameon=True,
        framealpha=0.8,
        borderpad=0.6,
    )

# Example depth tuning curves of 4 more neurons (Cell 3, 4, 6, 7; running vs
# stationary), arranged 2x2 to the left of the example FOV
if True:
    depth_tuning_kwargs = dict(
        rs_thr=None,
        plot_fit=True,
        plot_smooth=False,
        linewidth=1.5,
        linecolor="royalblue",
        closed_loop=1,
        fontsize_dict=fontsize_dict,
        markersize=8,
        markeredgecolor="w",
    )
    grid_indices = [
        1,
        2,
        4,
        5,
    ]  # roi_num 3, 4, 6, 7 in EXAMPLE_ROIS (2 and 5 excluded here)
    grid_x0, grid_x1 = 0.02, 0.30
    grid_y0, grid_y1 = 0.47, 0.68
    grid_wspace, grid_hspace = 0.04, 0.02
    grid_col_width = (grid_x1 - grid_x0 - grid_wspace) / 2
    grid_row_height = (grid_y1 - grid_y0 - grid_hspace) / 2

    for grid_pos, i in enumerate(grid_indices):
        col, row = grid_pos // 2, grid_pos % 2
        x0 = grid_x0 + col * (grid_col_width + grid_wspace)
        y0 = grid_y1 - grid_row_height - row * (grid_row_height + grid_hspace)
        ax = fig_4ex.add_axes([x0, y0, grid_col_width, grid_row_height])
        label_pos = "upper_right" if col == 0 else "upper_left"
        roi_num = i + 2
        depth_selectivity_plots.plot_running_stationary_depth_tuning(
            roi=EXAMPLE_ROIS[i],
            roi_num=roi_num,
            i=i,
            neurons_df=neurons_df_example,
            trials_df=trials_df_example,
            ax=ax,
            fov_ax=fov_ax,
            ops=ops,
            stat=stat,
            depth_tuning_kwargs=depth_tuning_kwargs,
            fontsize_dict=fontsize_dict,
            legend_loc="upper right",
            text_pos=label_pos,
        )
        ax.yaxis.labelpad = 1
        ax.xaxis.labelpad = 1


# Histogram of preferred depths of all depth-tuned neurons, above the z-score raster
if True:
    # in the rightmost column, below the top-row Cell 1 tuning curve
    ax_pref_depth_hist = fig_4ex.add_axes((0.70, 0.4, 0.15, 0.07))
    depth_selectivity_plots.plot_preferred_depth_hist(
        results_df=neurons_df_all[(neurons_df_all["depth_tuned"] == 1)],
        use_col="preferred_depth_closedloop",
        nbins=20,
        fontsize_dict=fontsize_dict,
    )
    ax_pref_depth_hist.xaxis.labelpad = 1
    ax_pref_depth_hist.yaxis.labelpad = 1
    ax_pref_depth_hist.yaxis.set_tick_params(pad=1)


# Raster plot of preferred depths of all neurons (sorted by preferred depth), in the
if True:
    # rightmost column, below the preferred-depth histogram
    ax_psth_raster = fig_4ex.add_axes((0.7, 0.54, 0.27, 0.15))
    depth_selectivity_plots.plot_psth_raster(
        results_df=neurons_resp,
        depth_list=np.round(np.geomspace(5, 640, num=8)).astype(int),
        fontsize_dict=fontsize_dict,
    )
    CORRIDOR_M = 6.0   # metres of virtual corridor per depth block
    BLANK_WINDOW_M = 3.0    # blank_length: the *analysis window* either side. The blank
                            # is really a ~2 s ITI, so this is not a physical 3 m -- but
                            # it does define the bin edges, so bin width is exact.
    NBINS_FULL = 60         # nbins, before trimming
    TRIM = 10     
    nbins = ax_psth_raster.get_xticks()[0] * 2          # bins per depth block
    m_per_bin = (CORRIDOR_M + 2 * BLANK_WINDOW_M) / NBINS_FULL     # 0.2 m
    assert np.isclose(NBINS_FULL - 2 * TRIM, ax_psth_raster.get_xticks()[0] * 2)
    SCALEBAR_M = 6.0   # length we want to annotate
    x0 = BLANK_WINDOW_M / m_per_bin - TRIM                         # 5  -> 0 m
    x1 = x0 + CORRIDOR_M / m_per_bin                               # 35 -> 6 m
    ax_psth_raster.tick_params(axis="x", rotation=0)
    # x -> data units (tracks xlim), y -> axes fraction (tracks panel size)
    trans = ax_psth_raster.get_xaxis_transform()
    y_bar = 1.03                                               # just above the raster
    ax_psth_raster.plot(
        [x0, x1], [y_bar, y_bar],
        transform=trans, color="k", linewidth=2,
        solid_capstyle="butt", clip_on=False,
    )
    ax_psth_raster.text(
        (x0 + x1) / 2, y_bar + 0.03, f"{CORRIDOR_M:g} m of travel",
        transform=trans, ha="center", va="bottom",
        fontsize=fontsize_dict["legend"],
    )
    ax_psth_raster.xaxis.labelpad = 1
    ax_psth_raster.yaxis.labelpad = 1


# --- Multi-day tracking summary (from figsupp_multidays.ipynb) ---
md_cmap = plt.cm.copper  # change this to use a different colormap for the days
md_day_colors = md_cmap(np.linspace(0, 1, 5))
md_fontsize = fontsize_dict
# Proportion of depth-tuned neurons across days
if True:
    ax_md_left = fig_4ex.add_axes((0.8, 0.4, 0.12, 0.1))
    m = np.nanmean(fractions_depth_by_day, axis=0)
    std = np.nanstd(fractions_depth_by_day, axis=0)
    ax_md_left.fill_between(np.arange(5), m - std, m + std, color="k", alpha=0.2)
    ax_md_left.plot(m, linewidth=0.8, color="k", zorder=5)
    ax_md_left.scatter(
        np.arange(len(m)),
        m,
        c=np.arange(len(m)),
        cmap=md_cmap,
        marker="o",
        zorder=10,
        alpha=1,
    )
    ax_md_left.set_xlim(0, 4)
    ax_md_left.set_ylim(0, 1)
    ax_md_left.set_xticks(
        np.arange(5),
        labels=[f"Day {i}" for i in range(1, 6)],
        fontsize=md_fontsize["tick"],
    )
    ax_md_left.set_ylabel(
        "Proportion of\ndepth-tuned neurons", fontsize=md_fontsize["label"]
    )
    ax_md_left.tick_params(axis="both", labelsize=md_fontsize["tick"])
    ax_md_left.spines[["right", "top"]].set_visible(False)

# Day-N vs day-N+1 preferred-depth stability
if True:
    ax_md_right = fig_4ex.add_axes([0.02, 0.01, 0.2, 0.18], aspect="equal")
    tracked_pref_multiday = neurons_df_multiday[
        (neurons_df_multiday.tracking_uid_manual != "")
        & (neurons_df_multiday.depth_tuned)
    ]
    df_pivot_multiday = tracked_pref_multiday.pivot(
        index="tracking_uid_manual",
        columns="day",
        values="preferred_depth_closedloop_running",
    )
    x_vals, y_vals = [], []
    for day in range(1, 5):
        next_day = day + 1
        if day in df_pivot_multiday.columns and next_day in df_pivot_multiday.columns:
            valid_pairs = df_pivot_multiday[[day, next_day]].dropna()
            x_vals.extend(valid_pairs[day].values)
            y_vals.extend(valid_pairs[next_day].values)
    x_vals = np.array(x_vals) * 100
    y_vals = np.array(y_vals) * 100

    ax_md_right.scatter(x_vals, y_vals, alpha=0.5, s=10, color="k", edgecolors="none")
    min_val = min(x_vals.min(), y_vals.min())
    max_val = max(x_vals.max(), y_vals.max())
    ax_md_right.plot(
        [min_val, max_val], [min_val, max_val], "k--", alpha=0.5, linewidth=0.7
    )
    ax_md_right.set_xscale("log")
    ax_md_right.set_yscale("log")
    ax_md_right.set_xlabel(
        "Pref. virtual depth day $N$ (cm)", fontsize=md_fontsize["label"], labelpad=1
    )
    ax_md_right.set_ylabel(
        "Pref. virtual depth day $N{+}1$ (cm)", fontsize=md_fontsize["label"]
    )
    ax_md_right.tick_params(axis="both", labelsize=md_fontsize["tick"], pad=1)

    rho_md, p_md = spearmanr(x_vals, y_vals)
    ax_md_right.text(
        0.05,
        0.85,
        f"$\\rho = {rho_md:.2f}$\n$p = {p_md:.1e}$",
        transform=ax_md_right.transAxes,
        fontsize=md_fontsize["legend"],
    )
    sns.despine(ax=ax_md_right, offset=1, trim=False)

# Example tracked neurons' depth tuning curves across consecutive days, in
if True:
    # a 2x2 grid just left of the decoder error plot: one axis per cell with
    # all 5 days overlaid and colour-coded, plus a discrete colorbar legend
    # (design from figsupp_multidays.ipynb)
    from matplotlib.colors import ListedColormap, BoundaryNorm

    md_jitter_frac = 0.05  # x-offset (in log-depth units) between each day's points

    def offset_last_errorbar(ax, dx):
        """Shift the x-position of the errorbar container just added to ax by dx."""
        container = ax.containers[-1]
        data_line, _, barlinecols = container.lines
        data_line.set_xdata(data_line.get_xdata() + dx)
        for lc in barlinecols:
            lc.set_segments([seg + [dx, 0] for seg in lc.get_segments()])

    mid_x0, mid_x1 = 0.27, 0.52
    mid_y0, mid_y1 = 0.02, 0.23
    mid_wspace, mid_hspace = 0.03, 0.03
    cbar_width, cbar_gap = 0.015, 0
    grid_x1_md = mid_x1 - cbar_width - cbar_gap
    col_width = (grid_x1_md - mid_x0 - mid_wspace) / 2
    row_height = (mid_y1 - mid_y0 - mid_hspace) / 2

    for i_col, tid in enumerate(example_tids_multiday):
        pos_col, pos_row = i_col % 2, i_col // 2
        x0 = mid_x0 + pos_col * (col_width + mid_wspace)
        y0 = mid_y1 - row_height - pos_row * (row_height + mid_hspace)
        ax = fig_4ex.add_axes((x0, y0, col_width, row_height))

        neuron_days = neurons_df_multiday[
            neurons_df_multiday.tracking_uid_manual == tid
        ].sort_values("day")
        ymax = 0
        for i_day, day in enumerate(range(1, 6)):
            row = neuron_days[neuron_days.day == day].iloc[0]
            sess_name = row["session"]
            roi_idx = int(row["roi"])

            if sess_name not in trials_df_cache_multiday:
                _, trials_df_md = spheres.sync_all_recordings(
                    session_name=sess_name,
                    flexilims_session=flexilims_session_multiday,
                    project=multiday_project,
                    filter_datasets={"anatomical_only": 3, "annotated": True},
                    recording_type="two_photon",
                    protocol_base="SpheresPermTubeReward",
                    photodiode_protocol=5,
                    return_volumes=True,
                )
                trials_df_cache_multiday[sess_name] = trials_df_md

            neurons_this_day = neurons_df_multiday[
                neurons_df_multiday.session == sess_name
            ].set_index("roi")

            mean_dff_arr = (
                depth_selectivity_plots.find_depth_neurons.average_dff_for_all_trials(
                    trials_df=trials_df_cache_multiday[sess_name],
                    rs_thr=0.05,
                    rs_thr_max=None,
                    still_only=0,
                    still_time=0,
                    frame_rate=15,
                    closed_loop=1,
                    param="depth",
                )[:, :, roi_idx]
            )
            CI_low, CI_high = depth_selectivity_plots.common_utils.get_bootstrap_ci(
                mean_dff_arr
            )
            curve_ylim = (
                np.nanmin(CI_low),
                depth_selectivity_plots.common_utils.ceil(np.nanmax(CI_high), 2),
            )
            ymax = max(ymax, curve_ylim[1])

            depth_selectivity_plots.plot_depth_tuning_curve(
                neurons_df=neurons_this_day,
                trials_df=trials_df_cache_multiday[sess_name],
                roi=roi_idx,
                rs_thr=0.05,
                rs_thr_max=None,
                still_only=0,
                still_time=0,
                use_col="depth_tuning_popt_closedloop_running",
                linecolor=md_day_colors[i_day],
                ylim=(0, ymax),
                ax=ax,
                **depth_tuning_kwargs_multiday,
            )
            offset_last_errorbar(ax, (i_day - 2) * md_jitter_frac)
            pref_depth = row["preferred_depth_closedloop_running"]
            ax.plot(
                np.log(pref_depth),
                1.02,
                marker="v",
                color=md_day_colors[i_day],
                markersize=3,
                clip_on=False,
                transform=ax.get_xaxis_transform(),
            )

        ax.set_ylim(0, ymax * 1.05)
        if pos_col == 0:
            ax.set_ylabel(r"$\Delta$F/F", fontsize=md_fontsize["label"])
        else:
            ax.set_ylabel("")
        if pos_row == 1:
            ax.set_xlabel("Depth (cm)", fontsize=md_fontsize["label"])
            ax.tick_params(axis="x", rotation=45, labelsize=md_fontsize["tick"])
        else:
            ax.set_xlabel("")
            ax.set_xticklabels([])
        ax.tick_params(axis="y", labelsize=md_fontsize["tick"])
        sns.despine(ax=ax, offset=1, trim=True)

    md_discrete_cmap = ListedColormap(md_day_colors)
    md_day_norm = BoundaryNorm(np.arange(0.5, 6.5, 1), md_discrete_cmap.N)
    md_day_sm = plt.cm.ScalarMappable(cmap=md_discrete_cmap, norm=md_day_norm)
    md_cax = fig_4ex.add_axes(
        (grid_x1_md + cbar_gap, mid_y0 + row_height * 0.4, cbar_width, row_height * 1.5)
    )
    md_cbar = fig_4ex.colorbar(md_day_sm, cax=md_cax, ticks=np.arange(1, 6))
    md_cbar.ax.set_yticks([])
    for iday in np.arange(1, 6):
        md_cax.text(
            0.5,
            (iday - 0.5) / 5.0,
            f"Day {iday}",
            color="w",
            transform=md_cax.transAxes,
            rotation=90,
            va="center",
            ha="center",
            fontsize=md_fontsize["legend"],
        )
    md_cbar.ax.minorticks_off()
    md_cbar.ax.tick_params(length=plt.rcParams["ytick.major.size"] / 3)
    md_cbar.outline.set_visible(False)


# DECODER ANALYSIS
if True:
    # Plot decoder error for different running speed bins, in the bottom row after the
    # multi-day example-cell grid
    ax1 = fig_4ex.add_axes((0.65, 0.01, 0.02, 0.15))
    ax2 = fig_4ex.add_axes((0.68, 0.01, 0.08, 0.15))
    _ = depth_decoder_plots.plot_decoder_err_by_speeds(
        decoder_df,
        np.insert(np.linspace(0.2, 2, 10), 0, 0.05),
        axes=[ax1, ax2],
        closed_loop=1,
        linecolor="k",
        linecolor_chance="k",
        linewidth=1,
        linewidth_chance=0.5,
        alpha=1,
        alpha_chance=1,
        markersize=5,
        fontsize_dict=fontsize_dict,
    )
    ax1.set_ylim([0, 3])
    ax2.set_ylim([0, 3])

    # Plot confusion matrix for stationary & best running speed bin, stacked in a single
    # column (stationary above running) at the right end of the bottom row
    for iplot, (title, colorbar_on) in enumerate(
        zip(["Stationary", "Running speed\n40 - 60 cm/s"], [0, 1])
    ):
        y0 = 0.18 if iplot == 0 else 0.04
        ax = fig_4ex.add_axes((0.85, y0, 0.13, 0.13))
        ax.text(
            0.95,
            0.95,
            title,
            transform=ax.transAxes,
            ha="right",
            va="top",
            fontsize=fontsize_dict["title"],
            color="w",
        )
        depth_decoder_plots.plot_confusion_matrix(
            conmats[iplot],
            ax,
            vmax,
            fontsize_dict,
            depths=depths,
            colorbar_on=colorbar_on,
            xtick_rotation=45,
        )
        # ax.set_title(title, fontsize=fontsize_dict["title"])
        if iplot == 0:
            ax.set_xlabel("")
            ax.set_xticklabels([])
            ax.set_ylabel("")

fig_4ex.savefig(SAVE_ROOT / "fig1_4examples.svg", bbox_inches="tight", dpi=300)

# %%
# Print N for multi day plots
# Print the number of sessions and mice for the prop depth tune per day
n_sessions_md = neurons_df_multiday.session.nunique()
n_mice_md = neurons_df_multiday.mouse.nunique()  # == fractions_depth_by_day.shape[0]
print(f"Prop. depth-tuned per day: {n_sessions_md} sessions, {n_mice_md} mice")

# Number of neurons for day N vs day N+1
tracked_uids_md = set()
for day in range(1, 5):
    next_day = day + 1
    if day in df_pivot_multiday.columns and next_day in df_pivot_multiday.columns:
        valid_pairs = df_pivot_multiday[[day, next_day]].dropna()
        tracked_uids_md.update(valid_pairs.index)
        print(f"Day {day} vs {next_day}: {len(valid_pairs)} neuron pairs")
print(f"Total day-N vs day-N+1: {len(x_vals)} pairs from {len(tracked_uids_md)} tracked neurons")

# %%
# Separate figure: histogram of proportion of depth-tuned neurons per session
fig_depth_neuron_perc = plt.figure(figsize=(6 * cm, 6 * cm))
fig_depth_neuron_perc.add_axes([0.2, 0.2, 0.7, 0.7])
depth_selectivity_plots.plot_depth_neuron_perc_hist(
    results_df=neurons_df_all,
    bins=np.arange(0, 1.0, 0.1),
    ylim=(0, 35),
    fontsize_dict=fontsize_dict,
)

# %%
fontsize_dict
