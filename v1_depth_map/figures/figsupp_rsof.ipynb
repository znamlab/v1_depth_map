# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import flexiznam as flz
from cottage_analysis.analysis import spheres, common_utils
from cottage_analysis.pipelines import pipeline_utils
from cottage_analysis.plotting import depth_selectivity_plots, rsof_plots
from cottage_analysis.summary_analysis import get_session_list, summary_utils
from cottage_analysis.plotting import style

# %%
# Register the manuscript font faces (Arial regular + bold + italic, Arial Narrow) and
# apply the publication rcParams: vector fonttypes, font sizes, tick/label padding.
# `style.savefig` then expands the SVG `font:` shorthand so Illustrator reads the
# family, size and weight correctly - see cottage_analysis.plotting.style for both.
from cottage_analysis.plotting import style
from cottage_analysis.plotting.style import CM, FONTSIZE_DICT

style.setup_figure_fonts()

# %%
project = "hey2_3d-vision_foodres_20220101"
flexilims_session = flz.get_flexilims_session(project)
from v1_depth_map.paths import get_figures_roots

READ_ROOT, SAVE_ROOT = get_figures_roots(flexilims_session)
SAVE_ROOT.mkdir(parents=True, exist_ok=True)
(SAVE_ROOT / "fig2").mkdir(parents=True, exist_ok=True)

recompute_summary = False  # True: rebuild the concatenated results_all from per-session pickles and re-cache; False: load fig2's cached combined parquet

# %%
# LOAD DATA
# Load an example session
project = "hey2_3d-vision_foodres_20220101"
session_name = "PZAH8.2h_S20230116"
flexilims_session = flz.get_flexilims_session(project)

vs_df_example, trials_df_example = spheres.sync_all_recordings(
    session_name=session_name,
    flexilims_session=flexilims_session,
    project=project,
    filter_datasets={"anatomical_only": 3, "ast_neuropil": False},
    recording_type="two_photon",
    protocol_base="SpheresPermTubeReward",
    photodiode_protocol=5,
    return_volumes=True,
)

neurons_ds_example = pipeline_utils.create_neurons_ds(
    session_name=session_name,
    flexilims_session=flexilims_session,
    project=None,
    conflicts="skip",
)
neurons_df_example = pd.read_pickle(neurons_ds_example.path_full)

# %%
# Concatenate all sessions for closedloop rsof
# The cached table is the one `figure_rsof_integration.ipynb` (fig2) writes, so the main
# figure and this supplement are guaranteed to describe the same population.
models = ["gof", "grs", "gadd", "g2d", "gratio"]
model_labels = ["OF only", "RS only", "Additive", "Conjunctive", "Pure depth"]
cols = [
    "roi",
    "best_depth",
    "preferred_depth_closedloop",
    "preferred_depth_closedloop_crossval",
    "depth_tuning_popt_closedloop",
    "depth_tuning_test_rsq_closedloop",
    "depth_tuning_test_spearmanr_pval_closedloop",
    "depth_tuning_test_spearmanr_rval_closedloop",
    "preferred_RS_closedloop_g2d",
    "preferred_RS_closedloop_crossval_g2d",
    "preferred_OF_closedloop_g2d",
    "preferred_OF_closedloop_crossval_g2d",
]
cols_to_add = [
    "rsof_test_rsq_closedloop_",
    "rsof_rsq_closedloop_",
    "rsof_popt_closedloop_",
]
for model in models:
    for col in cols_to_add:
        cols.append(f"{col}{model}")

if recompute_summary:
    mouse_list = flz.get_entities("mouse", flexilims_session=flexilims_session)
    mouse_list = mouse_list[
        mouse_list.name.isin(
            [
                "PZAH6.4b",
                "PZAG3.4f",
                "PZAH8.2h",
                "PZAH8.2i",
                "PZAH8.2f",
                "PZAH10.2d",
                "PZAH10.2f",
            ]
        )
    ]
    results_all = summary_utils.concatenate_all_neurons_df(
        flexilims_session=flexilims_session,
        session_list=get_session_list.get_sessions(
            flexilims_session,
            exclude_openloop=False,
            exclude_pure_closedloop=False,
            v1_only=True,
            trialnum_min=10,
            mouse_list=mouse_list,
        ),
        filename="neurons_df.pickle",
        cols=cols,
        read_iscell=True,
        verbose=True,
    )
    results_all["preferred_RS_closedloop_crossval_g2d"] = (
        results_all["preferred_RS_closedloop_crossval_g2d"] * 100
    )
    results_all["preferred_depth_closedloop_crossval"] = (
        results_all["preferred_depth_closedloop_crossval"] * 100
    )
    results_all["preferred_OF_closedloop_crossval_g2d"] = np.degrees(
        results_all["preferred_OF_closedloop_crossval_g2d"]
    )
    # Same slimming and same file as figure_rsof_integration.ipynb, so whichever notebook
    # rebuilds the cache writes an identical table.
    cols_to_keep = [
        col
        for col in results_all.columns
        if not any(x in col for x in ["rf_coef", "dff_stim"])
    ]
    results_all = results_all[cols_to_keep].copy()
    results_all.to_parquet(SAVE_ROOT / "fig2" / "results_all_rsof_closedloop.parquet")
else:
    results_all = pd.read_parquet(
        READ_ROOT / "fig2" / "results_all_rsof_closedloop.parquet"
    )

# Drop non-cells up front, as fig2 does, so the empirical-null thresholds below are fitted
# on curated cells only.
results_all = results_all[results_all["iscell"]].copy()

# %%
# Helper plot function to draw the five preferred-RS/OF vs preferred-depth panels at their fixed coordinates.
# Vertical placement of the four preferred-RS panels: GRID_TOP is the bottom edge of the
# upper row and GRID_ROW_GAP the drop to the lower one. The two shared axis labels are
# positioned from the same numbers, so the whole block moves as one.
GRID_TOP = 0.575
GRID_ROW_GAP = 0.18
GRID_H = 0.15


def plot_rsof_scatter_panels(
    fig, neurons_df, fontsize_dict=FONTSIZE_DICT, alpha=0.4, rasterized=True
):
    """Draw the five preferred-RS/OF vs preferred-depth panels at their fixed coordinates.

    Factored out so the same panels can be redrawn for a different neuron selection (see
    the legacy-criterion comparison cell below) without the two versions drifting apart.
    """
    # Plot preferred_depth - preferred_of scatter
    rsof_plots.plot_2d_hist(
        fig=fig,
        neurons_df=neurons_df,
        xcol="preferred_OF_closedloop_crossval_g2d",
        ycol="preferred_depth_closedloop_crossval",
        xlabel="Preferred optic flow speed (degrees/s)",
        ylabel="Preferred virtual depth (cm)",
        plot_x=0.6,
        plot_y=0.75,
        plot_width=0.35,
        plot_height=0.25,
        aspect_equal=True,
        fontsize_dict=fontsize_dict,
        color="royalblue",
        contour_color="k",
        linewidth=1,
        s=2,
        alpha=alpha,
        rasterized=rasterized,
    )
    plt.gca().set_aspect("equal")

    # Plot preferred_depth - preferred_rs scatter at different bins of preferred_of
    rsof_plots.plot_2d_hist(
        fig=fig,
        neurons_df=neurons_df,
        xcol="preferred_RS_closedloop_crossval_g2d",
        ycol="preferred_depth_closedloop_crossval",
        xlabel="",
        ylabel="",
        plot_x=0.6,
        plot_y=GRID_TOP,
        plot_width=GRID_H,
        plot_height=GRID_H,
        aspect_equal=True,
        fontsize_dict=fontsize_dict,
        color="royalblue",
        contour_color="k",
        linewidth=1,
        s=1,
        alpha=alpha,
        rasterized=rasterized,
    )
    plt.gca().set_aspect("equal")
    plt.title("All depth-selective cells", fontsize=fontsize_dict["label"])

    for i, (of_min, of_max) in enumerate(zip([1, 10, 100], [10, 100, 1000])):
        results_filtered = neurons_df[
            (neurons_df["preferred_OF_closedloop_crossval_g2d"] >= of_min)
            & (neurons_df["preferred_OF_closedloop_crossval_g2d"] < of_max)
        ]
        rsof_plots.plot_2d_hist(
            fig=fig,
            neurons_df=results_filtered,
            xcol="preferred_RS_closedloop_crossval_g2d",
            ycol="preferred_depth_closedloop_crossval",
            xlabel="",
            ylabel="",
            plot_x=0.6 + (i + 1) % 2 * 0.2,
            plot_y=GRID_TOP - (i + 1) // 2 * GRID_ROW_GAP,
            plot_width=GRID_H,
            plot_height=GRID_H,
            aspect_equal=True,
            fontsize_dict=fontsize_dict,
            linewidth=1,
            color="royalblue",
            contour_color="k",
            s=1,
            alpha=alpha,
            rasterized=rasterized,
        )
        plt.gca().set_aspect("equal")
        plt.title(f"{of_min}-{of_max} degrees/s OF", fontsize=fontsize_dict["label"])

    fig.text(
        0.560,
        GRID_TOP + (GRID_H - GRID_ROW_GAP) / 2,
        "Preferred virtual depth (cm)",
        fontsize=fontsize_dict["label"],
        va="center",
        ha="center",
        rotation="vertical",
    )
    fig.text(
        0.765,
        # just under the lower row's tick labels
        GRID_TOP - GRID_ROW_GAP - 0.02,
        "Preferred running speed (cm/s)",
        fontsize=fontsize_dict["label"],
        va="top",
        ha="center",
    )

# %%
# Panel O: how the RS/OF model comparison depends on response amplitude. This is the
# stacked-bar figure that `figure_rsof_integration.ipynb` builds but does not place in
# fig2, drawn at fixed coordinates so it can be dropped straight into this supplement's
# layout.
import seaborn as sns

# Bin edges on the peak amplitude of the gaussian depth-tuning fit (dF/F). Neurons with
# an amplitude above the last edge fall outside every bin and are dropped (`pd.cut`
# returns NaN), which is what the main-figure version does too.
AMPLITUDE_BINS = np.arange(0.0, 1.03, 0.03)
# One colour per model, matching the order the model fits are plotted in above.
MODEL_COLORS = {
    "gof": "tab:blue",
    "grs": "tab:orange",
    "gadd": "tab:red",
    "g2d": "tab:purple",
    "gratio": "tab:green",
}


def _bin_by_amplitude(neurons_df, bins=AMPLITUDE_BINS):
    """Add an `amplitude_bin` column; return (df, bin categories)."""
    df = neurons_df.copy()
    df["amplitude_bin"] = pd.cut(df["preferred_depth_amplitude"], bins=bins)
    return df, df["amplitude_bin"].cat.categories


def plot_best_model_by_amplitude(
    fig,
    neurons_df,
    models,
    model_labels,
    plot_x,
    plot_y,
    plot_width,
    plot_height,
    hist_height=0.045,
    gap=0.015,
    step=5,
    fontsize_dict=FONTSIZE_DICT,
):
    """Proportion of neurons best fit by each model, per depth-tuning amplitude bin.

    Each neuron is assigned to the model with the highest closed-loop test R2, so the
    bars sum to 1 within a bin. The strip underneath gives the number of neurons per
    bin (log scale) at the same bar positions, since the extreme bins are sparse.

    `plot_y` is the bottom of that strip; the stacked bars sit `hist_height + gap`
    above it. Returns (bar axes, count axes) - the caller draws the legend, using the
    bar axes' handles.
    """
    df, categories = _bin_by_amplitude(neurons_df)
    rsq_cols = [f"rsof_test_rsq_closedloop_{model}" for model in models]
    bar_x = np.arange(len(categories))

    ax_hist = fig.add_axes([plot_x, plot_y, plot_width, hist_height])
    ax = fig.add_axes([plot_x, plot_y + hist_height + gap, plot_width, plot_height])

    counts = df["amplitude_bin"].value_counts().reindex(categories)
    ax_hist.bar(bar_x, counts.values, width=1, color="grey")
    ax_hist.semilogy()
    ax_hist.set_ylabel("N", fontsize=fontsize_dict["label"])
    ax_hist.set_xlabel(
        "Peak amplitude of depth tuning fit ($\\Delta$F/F)",
        fontsize=fontsize_dict["label"],
    )
    ax_hist.set_xticks(bar_x[::step])
    ax_hist.set_xticklabels(
        [f"{b.left:.2g}" for b in categories][::step],
        fontsize=fontsize_dict["tick"],
    )
    ax_hist.tick_params(axis="y", labelsize=fontsize_dict["tick"])

    # Stack bottom-to-top in `models` order, so the stack reads the same way as the
    # model-fit columns of the example cells above.
    bottoms = np.zeros(len(categories))
    for model, label in zip(models, model_labels):
        heights = np.array(
            [
                (
                    df.loc[df["amplitude_bin"] == b, rsq_cols]
                    .idxmax(axis=1)
                    .eq(f"rsof_test_rsq_closedloop_{model}")
                    .mean()
                    if (df["amplitude_bin"] == b).any()
                    else 0.0
                )
                for b in categories
            ]
        )
        ax.bar(
            bar_x,
            heights,
            bottom=bottoms,
            width=1,
            color=MODEL_COLORS[model],
            label=label.replace("\n", " "),
        )
        bottoms += heights

    ax.set_xlim(ax_hist.get_xlim())
    ax.set_xticks(bar_x[::step])
    ax.set_xticklabels([])
    ax.set_ylim([0, 1])
    ax.set_yticks([0, 0.5, 1])
    ax.set_ylabel(
        "Proportion of neurons\nwith best model fit", fontsize=fontsize_dict["label"]
    )
    ax.tick_params(axis="y", labelsize=fontsize_dict["tick"])
    sns.despine(ax=ax, offset=2)
    sns.despine(ax=ax_hist, offset=2)
    return ax, ax_hist

# %%
import string

# Three example cells, ordered near -> far by preferred depth. The near one was picked
# from the example session as the depth-tuned neuron with the best combination of depth
# tuning (test R2 = 0.56, gaussian amplitude 0.95 dF/F) and RS/OF fit (g2d test
# R2 = 0.37) among those preferring < 15 cm; 402 and 86 are the mid (0.8 m) and far
# (3.2 m) cells the figure already showed.
EXAMPLE_ROIS = [
    261,
    402,
    86,
]
fontsize_dict = FONTSIZE_DICT
model_labels = ["Optic\nflow", "Running\nspeed", "Additive", "Conjunctive", "RS/OF"]
results_all["preferred_depth_amplitude"] = results_all[
    "depth_tuning_popt_closedloop"
].apply(lambda x: np.exp(x[0]) + x[-1])

# ---------------------------------------------------------------------------
# Vertical layout of the example-cell column, in figure fractions. Each cell is two
# rows: the tuning curves (depth, RS, OF), then the measured RS/OF matrix and the five
# model fits. A gap only has to hold the text that falls between two rows, so it is set
# from what is actually there rather than left at a uniform value: the model names are
# only written above the first cell's fits, and only the gap below a matrix row has to
# clear a panel letter.
# ---------------------------------------------------------------------------
TUNING_H = 0.08  # height of a tuning-curve row
MATRIX_H = 0.10  # height of a matrix / model-fit row
ROW_GAP = 0.05  # tuning row -> matrix row of the same cell
ROW_GAP_TITLED = 0.07  # same, but leaving room for the model-name titles
CELL_GAP = 0.055  # matrix row -> next cell's tuning row
COLUMN_TOP = 0.965

tuning_y, matrix_y = [], []
row_top = COLUMN_TOP
for iroi in range(len(EXAMPLE_ROIS)):
    tuning_y.append(row_top - TUNING_H)
    gap = ROW_GAP_TITLED if iroi == 0 else ROW_GAP
    matrix_y.append(tuning_y[-1] - gap - MATRIX_H)
    row_top = matrix_y[-1] - CELL_GAP

# The response-amplitude panel sits at the bottom of the right-hand column, under the
# preferred-RS/OF scatter grid, and is as wide as the scatter above it. AMP_Y is the
# bottom of the stacked bars; the neuron-count strip goes below them.
AMP_X = 0.67
AMP_W = 0.28
AMP_Y = 0.205
AMP_H = 0.13

# Plot 3 example cells with depth tuning, rs tuning, of tuning, and rsof matrix
fig = plt.figure(figsize=(18 / 2.54, 21 / 2.54))

# Panel letters. The example-cell column takes two per row (tuning curves: depth, then
# speed; matrix row: measured, then fitted), so it uses four letters per cell and the
# right-hand panels carry on from wherever that ends.
letter_coords = []
for t_y, m_y in zip(tuning_y, matrix_y):
    letter_coords += [
        (0.01, t_y + TUNING_H + 0.02),
        (0.17, t_y + TUNING_H + 0.02),
        (0.01, m_y + MATRIX_H + 0.02),
        (0.16, m_y + MATRIX_H + 0.02),
    ]
letter_coords += [
    (0.57, 0.98),  # preferred OF vs preferred depth
    (0.57, 0.715),  # preferred RS vs preferred depth, split by preferred OF
    (0.60, AMP_Y + AMP_H + 0.02),  # best model vs response amplitude
]
panel_coords = dict(zip(string.ascii_uppercase, letter_coords))
for p, (px, py) in panel_coords.items():
    fig.text(px, py, p, fontsize=fontsize_dict["panel"], fontweight="bold", va="top")

for iroi, roi in enumerate(EXAMPLE_ROIS):
    fig.add_axes([0.05, tuning_y[iroi], 0.1, TUNING_H])
    depth_tuning_kwargs = dict(
        rs_thr=None,
        plot_fit=True,
        plot_smooth=False,
        linewidth=1.2,
        linecolor="royalblue",
        closed_loop=1,
        fontsize_dict=fontsize_dict,
        markersize=7,
        markeredgecolor="w",
    )
    depth_selectivity_plots.plot_depth_tuning_curve(
        neurons_df=neurons_df_example,
        trials_df=trials_df_example,
        roi=roi,
        **depth_tuning_kwargs,
    )
    ax = fig.add_axes([0.21, tuning_y[iroi], 0.11, TUNING_H])
    rsof_plots.plot_speed_tuning(
        trials_df=trials_df_example,
        roi=roi,
        is_closed_loop=1,
        nbins=15,
        which_speed="RS",
        speed_min=0,
        speed_max=1.5,
        speed_thr=0,
        smoothing_sd=1,
        markersize=2.5,
        linewidth=0.8,
        markeredgecolor="w",
        fontsize_dict=fontsize_dict,
        legend_on=False,
    )
    ylim = plt.gca().get_ylim()
    plt.xlabel("Running speed\n(cm/s)", fontsize=fontsize_dict["label"])
    ax = fig.add_axes([0.36, tuning_y[iroi], 0.11, TUNING_H])
    rsof_plots.plot_speed_tuning(
        trials_df=trials_df_example,
        roi=roi,
        is_closed_loop=1,
        nbins=20,
        which_speed="OF",
        speed_min=0.01,
        speed_max=1.5,
        speed_thr=0.01,
        of_min=1e-2,
        of_max=1e4,
        smoothing_sd=1,
        markersize=2.5,
        linewidth=0.8,
        markeredgecolor="w",
        fontsize_dict=fontsize_dict,
        legend_on=True,
        ylim=ylim,
    )
    plt.gca().set_ylabel("")
    plt.gca().set_yticklabels([])
    plt.xlabel("Optic flow speed\n(degrees/s)", fontsize=fontsize_dict["label"])

    ax = fig.add_axes([0.05, matrix_y[iroi], 0.1, MATRIX_H])
    vmin, vmax = rsof_plots.plot_RS_OF_matrix(
        trials_df=trials_df_example,
        roi=roi,
        log_range={
            "rs_bin_log_min": 0,
            "rs_bin_log_max": 2.5,
            "rs_bin_num": 6,
            "of_bin_log_min": -1.5,
            "of_bin_log_max": 3.5,
            "of_bin_num": 11,
            "log_base": 10,
        },
        is_closed_loop=1,
        vmin=None,
        vmax=None,
        xlabel="Running speed (cm/s)",
        ylabel="Optic flow speed\n(degrees/s)",
        cbar_width=None,
        fontsize_dict=fontsize_dict,
    )

    # Clean colorbar matching manuscript style
    cax = fig.add_axes([0.151, matrix_y[iroi], 0.005, 0.05])
    norm = matplotlib.colors.Normalize(vmin=vmin, vmax=vmax)
    cbar = fig.colorbar(matplotlib.cm.ScalarMappable(norm=norm, cmap="Reds"), cax=cax)
    vmax_tick = np.ceil(vmax * 10) / 10
    cbar.set_ticks([vmin, vmax])
    cbar.set_ticklabels(["0.0", f"{vmax_tick:.1f}"])
    cax.tick_params(labelsize=fontsize_dict["tick"], length=2, pad=1.5)
    cax.set_title(r"$\Delta$F/F", fontsize=fontsize_dict["legend"], pad=2, ha="center")

    # Plot 5 model fits
    for imodel, (model, model_label) in enumerate(zip(models, model_labels)):
        ylabel = ""
        if imodel == 2:
            xlabel = "Running speed (cm/s)"
        else:
            xlabel = ""

        ax = fig.add_axes([0.18 + 0.07 * imodel, matrix_y[iroi], 0.085, 0.085])
        rsof_plots.plot_RS_OF_fit(
            neurons_df=neurons_df_example,
            roi=roi,
            model=model,
            # The model names label the column once, above the first example cell.
            model_label=model_label if iroi == 0 else "",
            min_sigma=0.25,
            vmin=vmin,
            vmax=vmax,
            log_range={
                "rs_bin_log_min": 0,
                "rs_bin_log_max": 2.5,
                "rs_bin_num": 6,
                "of_bin_log_min": -1.5,
                "of_bin_log_max": 3.5,
                "of_bin_num": 11,
                "log_base": 10,
            },
            xlabel=xlabel,
            ylabel=ylabel,
            fontsize_dict=fontsize_dict,
            cbar_width=None,
        )
        if imodel > 0:
            ax.set_yticks([])
        ax.set_ylabel("")

common_utils.add_one_sided_spearman_significance(
    results_all,
    rval_col="depth_tuning_test_spearmanr_rval_closedloop",
    pval_col="depth_tuning_test_spearmanr_pval_closedloop",
    out_col="is_depth_neuron",
)

# RS/OF fit significance: same empirical-null method as fig2 (a threshold read off the
# mirrored negative tail of the test-R2 distribution) instead of a hard-coded cut-off.
# The null is fitted for all five models so the printed thresholds match fig2's, but only
# `g2d` gates the selection here, since every panel below plots g2d parameters - this is
# what fig2 panel K does for the treadmill population.
PERCENTILE = 95
model_rsq_cols = {model: f"rsof_test_rsq_closedloop_{model}" for model in models}
thresholds = common_utils.add_rsq_significance(
    results_all, model_rsq_cols, percentile=PERCENTILE
)

neurons_df = results_all[
    results_all["iscell"]
    & results_all["is_depth_neuron"]
    & results_all["rsof_test_rsq_closedloop_g2d_sig"]
]
print(
    f"g2d empirical null (thr={thresholds['g2d']:.5f}): n={len(neurons_df)}  |  "
    f"legacy R2>0.02: n={len(neurons_df_old)}"
)

plot_rsof_scatter_panels(fig, neurons_df, fontsize_dict=fontsize_dict, alpha=0.2)

# Response-amplitude panel. Selection is looser than for the scatters above -
# depth-tuned neurons with at least one significant RS/OF fit, rather than a significant
# `g2d` fit - because the panel asks which of the five models wins, so gating on one of
# them would bias the answer. All that is needed is that some model fits.
sig_cols = [f"rsof_test_rsq_closedloop_{model}_sig" for model in models]
neurons_df_amp = results_all[
    results_all["iscell"]
    & results_all["is_depth_neuron"]
    & results_all[sig_cols].any(axis=1)
]
n_above = int((neurons_df_amp["preferred_depth_amplitude"] > AMPLITUDE_BINS[-1]).sum())
print(
    f"amplitude panels: n={len(neurons_df_amp)} depth-tuned neurons with >=1 significant "
    f"model fit ({n_above} above the last amplitude bin, not plotted)"
)

ax_amp, _ = plot_best_model_by_amplitude(
    fig,
    neurons_df_amp,
    models=models,
    model_labels=model_labels,
    plot_x=AMP_X,
    plot_y=AMP_Y - 0.06,  # leaves room for the count strip between the two
    plot_width=AMP_W,
    plot_height=AMP_H,
    fontsize_dict=fontsize_dict,
)
# The legend goes under the panel rather than beside it: the panel runs to the right
# edge of the scatter above, so there is nothing to its right.
handles, labels = ax_amp.get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="upper left",
    bbox_to_anchor=(AMP_X, 0.095),
    ncol=3,
    fontsize=fontsize_dict["legend"],
    frameon=False,
    handlelength=1,
    columnspacing=1,
    labelspacing=0.3,
)

style.savefig(SAVE_ROOT / "fig_supp_rsof.svg", fig=fig, bbox_inches="tight", dpi=300)

# %%
# Comparison only, not a manuscript panel: the same scatters drawn for the legacy
# hard-coded criterion (g2d test R2 > 0.02), so the effect of moving to the empirical null
# is visible rather than argued. Same figsize and same axes coordinates as the figure
# above, so the two SVGs overlay panel-for-panel; the left half is empty here.
# Legacy hard-coded criterion, kept only for the comparison figure in the next cell.
neurons_df_old = results_all[
    results_all["iscell"]
    & results_all["is_depth_neuron"]
    & (results_all["rsof_test_rsq_closedloop_g2d"] > 0.02)
]

fig_old = plt.figure(figsize=(18 / 2.54, 21 / 2.54))
plot_rsof_scatter_panels(fig_old, neurons_df_old, fontsize_dict=fontsize_dict)
fig_old.suptitle(
    f"Legacy criterion: g2d R$^2$ > 0.02 (n={len(neurons_df_old)}) - "
    f"empirical null keeps n={len(neurons_df)}",
    fontsize=fontsize_dict["title"],
)

style.savefig(
    SAVE_ROOT / "fig_supp_rsof_legacy_criterion.svg",
    fig=fig_old,
    bbox_inches="tight",
    dpi=300,
)

# %% [markdown]
# ## Stats

# %%
# closedloop OF vs preferred depth
n_boots = 20000
xcol = ["preferred_OF_closedloop_crossval_g2d"]
ycol = ["preferred_depth_closedloop_crossval"]
np.random.seed(0)
r, distribution = common_utils.hierarchical_bootstrap_stats(
    neurons_df, n_boots, xcol, ["mouse", "session"], ycol=ycol, correlation=True
)
pval = common_utils.calculate_pval_from_bootstrap(distribution, value=0)
print(f"closedloop ratio vs preferred depth: r={r}, p={pval}")

# %%
# closedloop RS vs preferred depth
n_boots = 20000
xcol = ["preferred_RS_closedloop_crossval_g2d"]
ycol = ["preferred_depth_closedloop_crossval"]
np.random.seed(0)
r, distribution = common_utils.hierarchical_bootstrap_stats(
    neurons_df, n_boots, xcol, ["mouse", "session"], ycol=ycol, correlation=True
)
pval = common_utils.calculate_pval_from_bootstrap(distribution, value=0)
print(f"closedloop ratio vs preferred depth: r={r}, p={pval}")

for i, (of_min, of_max) in enumerate(zip([1, 10, 100], [10, 100, 1000])):
    results_filtered = neurons_df[
        (neurons_df["preferred_OF_closedloop_crossval_g2d"] >= of_min)
        & (neurons_df["preferred_OF_closedloop_crossval_g2d"] < of_max)
    ]
    r, distribution = common_utils.hierarchical_bootstrap_stats(
        results_filtered,
        n_boots,
        xcol,
        ["mouse", "session"],
        ycol=ycol,
        correlation=True,
    )
    pval = common_utils.calculate_pval_from_bootstrap(distribution, value=0)
    print(f"closedloop ratio vs preferred depth: r={r}, p={pval}")
