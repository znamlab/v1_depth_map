# %%
from ScanImageTiffReader import ScanImageTiffReader
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
d = 450
n = int((d+90)/10)
vol=ScanImageTiffReader(f"/camp/lab/znamenskiyp/data/instruments/raw_data/projects/changt_rabies_imaging_20230301/BRYC122.1c/S20230417/structural_800nm_00001_000{n}.tif").data();
root = Path('/camp/lab/znamenskiyp/home/shared/projects/changt_rabies_imaging_20230301/plots')
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(np.average(vol[-400::2,:,:], axis=0), vmax=300, cmap='Greys_r')
plt.axis('off')
plt.title(f'GCaMP8m Depth {d} um')
# plt.colorbar()

plt.subplot(122)
plt.imshow(np.average(vol[-399::2,:,:], axis=0), vmax=100, cmap='Greys_r')
plt.axis('off')
plt.title(f'mCherry Depth {d} um')
# plt.colorbar()
plt.savefig(root/(f'depth_{d}um.pdf'))
